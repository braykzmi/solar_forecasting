# %%
import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob
from scipy.optimize import curve_fit
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_error
import tensorflow as tf
from tensorflow.keras.layers import Dense
from scipy.interpolate import interp1d
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dropout

# %% [markdown]
# # I. Data Loading

# %%
# Loading the Monthly Solar Data
file_path = 'solar_data.xlsx'
sheet_name = 'solarbymonth'

# Read the Excel sheet into a Pandas DataFrame
monthly_data = pd.read_excel(file_path, sheet_name=sheet_name)

# Extract relevant columns
monthly_data['Month'] = pd.to_datetime(monthly_data['Month'])  # Ensure the 'Month' column is in datetime format
months = monthly_data['Month']
utility_gen = monthly_data['Utility Scale Generation']
small_scale_gen = monthly_data['Small Scale Generation']
total_solar = monthly_data['Total Solar']

# %%
# Plot the data
plt.figure(figsize=(14, 7))
plt.plot(months, utility_gen, label='Utility Scale Generation (MW)', color='green', linewidth=2)
plt.plot(months, small_scale_gen, label='Small Scale Generation (MW)', color='blue', linewidth=2)
plt.plot(months, total_solar, label='Total Solar Generation (MW)', color='orange', linewidth=2)
plt.xlabel('Month')
plt.ylabel('Generation (MW)')
plt.title('Monthly Solar Generation')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
# Loading the TSI Data
data_dir = 'tsi_monthly'

# Find all NetCDF files in the directory
file_paths = sorted(glob(os.path.join(data_dir, 'tsi_*.nc')))

# Initialize an empty list to store DataFrames
data_frames = []

# Loop through each file and load the data
for file_path in file_paths:
    # Open the NetCDF file
    dataset = xr.open_dataset(file_path)
    
    # Convert the dataset to a Pandas DataFrame and reset the index
    df = dataset.to_dataframe().reset_index()
    
    # Ensure the 'time' column is in datetime format
    df['time'] = pd.to_datetime(df['time'])
    
    # Append the DataFrame to the list
    data_frames.append(df)

all_data = pd.concat(data_frames, ignore_index=True)

# Verify loading
print(all_data.head())
# Out:
#         time  bounds          TSI   TSI_UNC  time_bnds
# 0 2014-01-15       0  1361.692383  0.152830 2014-01-01
# 1 2014-01-15       1  1361.692383  0.152830 2014-02-01
# 2 2014-02-15       0  1361.590088  0.173391 2014-02-01
# 3 2014-02-15       1  1361.590088  0.173391 2014-03-01
# 4 2014-03-15       0  1362.293213  0.133309 2014-03-01

# %%
# Loading the Exponential Regression Data

def exp_func(x, a, b):
    return a * np.exp(b * x)

file_path = 'solar_data.xlsx'
sheet_name = 'capacitygrowth'

# Read the Excel sheet into a Pandas DataFrame
solar_data = pd.read_excel(file_path, sheet_name=sheet_name)

# Sum the residential and commercial annual capacities into small scale
solar_data['Small Scale Annual'] = solar_data['Residential Annual'] + solar_data['Commercial Annual']
solar_data['Small Scale Cumul'] = solar_data['Residential Cumul'] + solar_data['Commercial Cumul']

# Extract relevant columns
years = solar_data['Year']
small_scale_annual = solar_data['Small Scale Annual']
utility_annual = solar_data['Utility Annual']
small_scale_cumul = solar_data['Small Scale Cumul']
utility_cumul = solar_data['Utility Cumul']

# Normalize the years to start from 0 for better numerical stability
normalized_years = years - years.min()

# Perform regression for small scale
params_small, _ = curve_fit(exp_func, normalized_years, small_scale_cumul, maxfev=10000)
small_scale_pred = exp_func(normalized_years, *params_small)

# Perform regression for utility
params_utility, _ = curve_fit(exp_func, normalized_years, utility_cumul, maxfev=10000)
utility_pred = exp_func(normalized_years, *params_utility)

# Verify loading
print(params_small)
print(params_utility)
# Out:
# [2.38570266e+03 2.05533322e-01]
# [3.00547526e+03 2.30188813e-01]

# %% [markdown]
# # I. TLNN Preliminary Testing

# %%
# Generate lagged features for TLNN
def create_lagged_features(data, lag, period):
    X, y = [], []
    for i in range(len(data) - lag * period):
        X.append([data[i + (j * period)] for j in range(lag)])
        y.append(data[i + lag * period])
    return np.array(X), np.array(y)

# %%
lag = 12  # Seasonal period
utility_gen_values = utility_gen.values  # Ensure the data is in numpy array format

# Create lagged features
X_lagged, y_lagged = create_lagged_features(utility_gen_values, lag=1, period=lag)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_lagged, y_lagged, test_size=0.2, random_state=42)

# %%
# Feature scaling
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

sc_y = StandardScaler()
y_train = sc_y.fit_transform(y_train.reshape(-1, 1))
y_test = sc_y.transform(y_test.reshape(-1, 1))

# %%
# Define the TLNN model
def create_tlnn(n_layers, n_activation, kernels):
    model = tf.keras.models.Sequential()
    for i, nodes in enumerate(n_layers):
        if i == 0:
            model.add(Dense(nodes, activation=n_activation, kernel_initializer=kernels, input_dim=X_train.shape[1]))
        else:
            model.add(Dense(nodes, activation=n_activation, kernel_initializer=kernels))
    model.add(Dense(1))  # Output layer
    model.compile(loss='mse', optimizer='adam', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# %%
# Create and summarize the model
tlnn = create_tlnn([32, 64], 'relu', 'normal')
tlnn.summary()
# Out:
# C:\Users\braykzmi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape            ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)              │            64 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)              │         2,112 │
# ├─────────────────────────────────┼─────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)               │            65 │
# └─────────────────────────────────┴─────────────────────────┴───────────────┘
#  Total params: 2,241 (8.75 KB)
#  Trainable params: 2,241 (8.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = tlnn.fit(X_train, y_train, batch_size=32, epochs=150, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/150
# 1/1 - 1s - 1s/step - loss: 0.9827 - root_mean_squared_error: 0.9913 - val_loss: 1.4898 - val_root_mean_squared_error: 1.2206
# Epoch 2/150
# 1/1 - 0s - 106ms/step - loss: 0.9700 - root_mean_squared_error: 0.9849 - val_loss: 1.4691 - val_root_mean_squared_error: 1.2121
# Epoch 3/150
# 1/1 - 0s - 101ms/step - loss: 0.9569 - root_mean_squared_error: 0.9782 - val_loss: 1.4490 - val_root_mean_squared_error: 1.2038
# Epoch 4/150
# 1/1 - 0s - 104ms/step - loss: 0.9443 - root_mean_squared_error: 0.9718 - val_loss: 1.4293 - val_root_mean_squared_error: 1.1955
# Epoch 5/150
# 1/1 - 0s - 101ms/step - loss: 0.9323 - root_mean_squared_error: 0.9655 - val_loss: 1.4106 - val_root_mean_squared_error: 1.1877
# Epoch 6/150
# 1/1 - 0s - 108ms/step - loss: 0.9205 - root_mean_squared_error: 0.9594 - val_loss: 1.3935 - val_root_mean_squared_error: 1.1804
# Epoch 7/150
# 1/1 - 0s - 92ms/step - loss: 0.9091 - root_mean_squared_error: 0.9534 - val_loss: 1.3769 - val_root_mean_squared_error: 1.1734
# Epoch 8/150
# 1/1 - 0s - 99ms/step - loss: 0.8977 - root_mean_squared_error: 0.9474 - val_loss: 1.3608 - val_root_mean_squared_error: 1.1665
# Epoch 9/150
# 1/1 - 0s - 98ms/step - loss: 0.8863 - root_mean_squared_error: 0.9415 - val_loss: 1.3445 - val_root_mean_squared_error: 1.1595
# Epoch 10/150
# 1/1 - 0s - 109ms/step - loss: 0.8750 - root_mean_squared_error: 0.9354 - val_loss: 1.3281 - val_root_mean_squared_error: 1.1524
# Epoch 11/150
# 1/1 - 0s - 110ms/step - loss: 0.8635 - root_mean_squared_error: 0.9293 - val_loss: 1.3113 - val_root_mean_squared_error: 1.1451
# Epoch 12/150
# 1/1 - 0s - 85ms/step - loss: 0.8518 - root_mean_squared_error: 0.9229 - val_loss: 1.2939 - val_root_mean_squared_error: 1.1375
# Epoch 13/150
# 1/1 - 0s - 92ms/step - loss: 0.8398 - root_mean_squared_error: 0.9164 - val_loss: 1.2764 - val_root_mean_squared_error: 1.1298
# Epoch 14/150
# 1/1 - 0s - 100ms/step - loss: 0.8274 - root_mean_squared_error: 0.9096 - val_loss: 1.2583 - val_root_mean_squared_error: 1.1218
# Epoch 15/150
# 1/1 - 0s - 106ms/step - loss: 0.8147 - root_mean_squared_error: 0.9026 - val_loss: 1.2395 - val_root_mean_squared_error: 1.1133
# Epoch 16/150
# 1/1 - 0s - 115ms/step - loss: 0.8015 - root_mean_squared_error: 0.8953 - val_loss: 1.2200 - val_root_mean_squared_error: 1.1045
# Epoch 17/150
# 1/1 - 0s - 106ms/step - loss: 0.7878 - root_mean_squared_error: 0.8876 - val_loss: 1.1999 - val_root_mean_squared_error: 1.0954
# Epoch 18/150
# 1/1 - 0s - 107ms/step - loss: 0.7737 - root_mean_squared_error: 0.8796 - val_loss: 1.1791 - val_root_mean_squared_error: 1.0859
# Epoch 19/150
# 1/1 - 0s - 91ms/step - loss: 0.7590 - root_mean_squared_error: 0.8712 - val_loss: 1.1578 - val_root_mean_squared_error: 1.0760
# Epoch 20/150
# 1/1 - 0s - 117ms/step - loss: 0.7440 - root_mean_squared_error: 0.8626 - val_loss: 1.1357 - val_root_mean_squared_error: 1.0657
# Epoch 21/150
# 1/1 - 0s - 110ms/step - loss: 0.7286 - root_mean_squared_error: 0.8536 - val_loss: 1.1129 - val_root_mean_squared_error: 1.0550
# Epoch 22/150
# 1/1 - 0s - 104ms/step - loss: 0.7128 - root_mean_squared_error: 0.8443 - val_loss: 1.0895 - val_root_mean_squared_error: 1.0438
# Epoch 23/150
# 1/1 - 0s - 108ms/step - loss: 0.6965 - root_mean_squared_error: 0.8346 - val_loss: 1.0653 - val_root_mean_squared_error: 1.0321
# Epoch 24/150
# 1/1 - 0s - 105ms/step - loss: 0.6798 - root_mean_squared_error: 0.8245 - val_loss: 1.0404 - val_root_mean_squared_error: 1.0200
# Epoch 25/150
# 1/1 - 0s - 109ms/step - loss: 0.6627 - root_mean_squared_error: 0.8141 - val_loss: 1.0149 - val_root_mean_squared_error: 1.0074
# Epoch 26/150
# 1/1 - 0s - 103ms/step - loss: 0.6453 - root_mean_squared_error: 0.8033 - val_loss: 0.9887 - val_root_mean_squared_error: 0.9943
# Epoch 27/150
# 1/1 - 0s - 89ms/step - loss: 0.6275 - root_mean_squared_error: 0.7921 - val_loss: 0.9619 - val_root_mean_squared_error: 0.9808
# Epoch 28/150
# 1/1 - 0s - 125ms/step - loss: 0.6093 - root_mean_squared_error: 0.7806 - val_loss: 0.9346 - val_root_mean_squared_error: 0.9667
# Epoch 29/150
# 1/1 - 0s - 108ms/step - loss: 0.5908 - root_mean_squared_error: 0.7686 - val_loss: 0.9067 - val_root_mean_squared_error: 0.9522
# Epoch 30/150
# 1/1 - 0s - 101ms/step - loss: 0.5720 - root_mean_squared_error: 0.7563 - val_loss: 0.8784 - val_root_mean_squared_error: 0.9372
# Epoch 31/150
# 1/1 - 0s - 96ms/step - loss: 0.5529 - root_mean_squared_error: 0.7436 - val_loss: 0.8497 - val_root_mean_squared_error: 0.9218
# Epoch 32/150
# 1/1 - 0s - 97ms/step - loss: 0.5335 - root_mean_squared_error: 0.7304 - val_loss: 0.8206 - val_root_mean_squared_error: 0.9058
# Epoch 33/150
# 1/1 - 0s - 94ms/step - loss: 0.5139 - root_mean_squared_error: 0.7169 - val_loss: 0.7911 - val_root_mean_squared_error: 0.8895
# Epoch 34/150
# 1/1 - 0s - 112ms/step - loss: 0.4942 - root_mean_squared_error: 0.7030 - val_loss: 0.7614 - val_root_mean_squared_error: 0.8726
# Epoch 35/150
# 1/1 - 0s - 115ms/step - loss: 0.4743 - root_mean_squared_error: 0.6887 - val_loss: 0.7316 - val_root_mean_squared_error: 0.8553
# Epoch 36/150
# 1/1 - 0s - 115ms/step - loss: 0.4543 - root_mean_squared_error: 0.6740 - val_loss: 0.7015 - val_root_mean_squared_error: 0.8376
# Epoch 37/150
# 1/1 - 0s - 110ms/step - loss: 0.4343 - root_mean_squared_error: 0.6590 - val_loss: 0.6713 - val_root_mean_squared_error: 0.8194
# Epoch 38/150
# 1/1 - 0s - 106ms/step - loss: 0.4143 - root_mean_squared_error: 0.6437 - val_loss: 0.6411 - val_root_mean_squared_error: 0.8007
# Epoch 39/150
# 1/1 - 0s - 102ms/step - loss: 0.3944 - root_mean_squared_error: 0.6280 - val_loss: 0.6110 - val_root_mean_squared_error: 0.7817
# Epoch 40/150
# 1/1 - 0s - 99ms/step - loss: 0.3746 - root_mean_squared_error: 0.6121 - val_loss: 0.5809 - val_root_mean_squared_error: 0.7622
# Epoch 41/150
# 1/1 - 0s - 109ms/step - loss: 0.3550 - root_mean_squared_error: 0.5959 - val_loss: 0.5510 - val_root_mean_squared_error: 0.7423
# Epoch 42/150
# 1/1 - 0s - 100ms/step - loss: 0.3357 - root_mean_squared_error: 0.5794 - val_loss: 0.5214 - val_root_mean_squared_error: 0.7221
# Epoch 43/150
# 1/1 - 0s - 100ms/step - loss: 0.3167 - root_mean_squared_error: 0.5627 - val_loss: 0.4920 - val_root_mean_squared_error: 0.7015
# Epoch 44/150
# 1/1 - 0s - 98ms/step - loss: 0.2980 - root_mean_squared_error: 0.5459 - val_loss: 0.4631 - val_root_mean_squared_error: 0.6805
# Epoch 45/150
# 1/1 - 0s - 103ms/step - loss: 0.2799 - root_mean_squared_error: 0.5290 - val_loss: 0.4347 - val_root_mean_squared_error: 0.6593
# Epoch 46/150
# 1/1 - 0s - 101ms/step - loss: 0.2622 - root_mean_squared_error: 0.5120 - val_loss: 0.4068 - val_root_mean_squared_error: 0.6378
# Epoch 47/150
# 1/1 - 0s - 129ms/step - loss: 0.2451 - root_mean_squared_error: 0.4951 - val_loss: 0.3797 - val_root_mean_squared_error: 0.6162
# Epoch 48/150
# 1/1 - 0s - 98ms/step - loss: 0.2287 - root_mean_squared_error: 0.4782 - val_loss: 0.3534 - val_root_mean_squared_error: 0.5945
# Epoch 49/150
# 1/1 - 0s - 110ms/step - loss: 0.2130 - root_mean_squared_error: 0.4615 - val_loss: 0.3279 - val_root_mean_squared_error: 0.5726
# Epoch 50/150
# 1/1 - 0s - 101ms/step - loss: 0.1980 - root_mean_squared_error: 0.4450 - val_loss: 0.3034 - val_root_mean_squared_error: 0.5508
# Epoch 51/150
# 1/1 - 0s - 113ms/step - loss: 0.1839 - root_mean_squared_error: 0.4289 - val_loss: 0.2800 - val_root_mean_squared_error: 0.5291
# Epoch 52/150
# 1/1 - 0s - 103ms/step - loss: 0.1707 - root_mean_squared_error: 0.4132 - val_loss: 0.2577 - val_root_mean_squared_error: 0.5076
# Epoch 53/150
# 1/1 - 0s - 103ms/step - loss: 0.1584 - root_mean_squared_error: 0.3980 - val_loss: 0.2365 - val_root_mean_squared_error: 0.4863
# Epoch 54/150
# 1/1 - 0s - 103ms/step - loss: 0.1471 - root_mean_squared_error: 0.3835 - val_loss: 0.2167 - val_root_mean_squared_error: 0.4655
# Epoch 55/150
# 1/1 - 0s - 126ms/step - loss: 0.1368 - root_mean_squared_error: 0.3698 - val_loss: 0.1981 - val_root_mean_squared_error: 0.4451
# Epoch 56/150
# 1/1 - 0s - 124ms/step - loss: 0.1274 - root_mean_squared_error: 0.3570 - val_loss: 0.1809 - val_root_mean_squared_error: 0.4253
# Epoch 57/150
# 1/1 - 0s - 95ms/step - loss: 0.1191 - root_mean_squared_error: 0.3451 - val_loss: 0.1651 - val_root_mean_squared_error: 0.4063
# Epoch 58/150
# 1/1 - 0s - 110ms/step - loss: 0.1118 - root_mean_squared_error: 0.3343 - val_loss: 0.1506 - val_root_mean_squared_error: 0.3881
# 1/1 - 0s - 92ms/step - loss: 0.0794 - root_mean_squared_error: 0.2817 - val_loss: 0.0673 - val_root_mean_squared_error: 0.2593
# Epoch 77/150
# 1/1 - 0s - 114ms/step - loss: 0.0784 - root_mean_squared_error: 0.2799 - val_loss: 0.0675 - val_root_mean_squared_error: 0.2599
# Epoch 78/150
# 1/1 - 0s - 99ms/step - loss: 0.0773 - root_mean_squared_error: 0.2780 - val_loss: 0.0681 - val_root_mean_squared_error: 0.2609
# Epoch 79/150
# 1/1 - 0s - 109ms/step - loss: 0.0762 - root_mean_squared_error: 0.2760 - val_loss: 0.0690 - val_root_mean_squared_error: 0.2626
# Epoch 80/150
# 1/1 - 0s - 109ms/step - loss: 0.0750 - root_mean_squared_error: 0.2739 - val_loss: 0.0704 - val_root_mean_squared_error: 0.2652
# Epoch 81/150
# 1/1 - 0s - 110ms/step - loss: 0.0739 - root_mean_squared_error: 0.2718 - val_loss: 0.0721 - val_root_mean_squared_error: 0.2686
# Epoch 82/150
# 1/1 - 0s - 100ms/step - loss: 0.0728 - root_mean_squared_error: 0.2698 - val_loss: 0.0741 - val_root_mean_squared_error: 0.2722
# Epoch 83/150
# 1/1 - 0s - 118ms/step - loss: 0.0717 - root_mean_squared_error: 0.2678 - val_loss: 0.0762 - val_root_mean_squared_error: 0.2761
# Epoch 84/150
# 1/1 - 0s - 120ms/step - loss: 0.0708 - root_mean_squared_error: 0.2661 - val_loss: 0.0785 - val_root_mean_squared_error: 0.2802
# Epoch 85/150
# 1/1 - 0s - 110ms/step - loss: 0.0700 - root_mean_squared_error: 0.2646 - val_loss: 0.0809 - val_root_mean_squared_error: 0.2845
# Epoch 86/150
# 1/1 - 0s - 102ms/step - loss: 0.0694 - root_mean_squared_error: 0.2634 - val_loss: 0.0834 - val_root_mean_squared_error: 0.2888
# Epoch 87/150
# 1/1 - 0s - 94ms/step - loss: 0.0689 - root_mean_squared_error: 0.2624 - val_loss: 0.0861 - val_root_mean_squared_error: 0.2933
# Epoch 88/150
# 1/1 - 0s - 104ms/step - loss: 0.0684 - root_mean_squared_error: 0.2616 - val_loss: 0.0887 - val_root_mean_squared_error: 0.2978
# Epoch 89/150
# 1/1 - 0s - 112ms/step - loss: 0.0681 - root_mean_squared_error: 0.2609 - val_loss: 0.0913 - val_root_mean_squared_error: 0.3022
# Epoch 90/150
# 1/1 - 0s - 101ms/step - loss: 0.0678 - root_mean_squared_error: 0.2603 - val_loss: 0.0937 - val_root_mean_squared_error: 0.3061
# Epoch 91/150
# 1/1 - 0s - 102ms/step - loss: 0.0675 - root_mean_squared_error: 0.2599 - val_loss: 0.0959 - val_root_mean_squared_error: 0.3097
# Epoch 92/150
# 1/1 - 0s - 110ms/step - loss: 0.0673 - root_mean_squared_error: 0.2594 - val_loss: 0.0977 - val_root_mean_squared_error: 0.3126
# Epoch 93/150
# 1/1 - 0s - 100ms/step - loss: 0.0671 - root_mean_squared_error: 0.2590 - val_loss: 0.0991 - val_root_mean_squared_error: 0.3148
# Epoch 94/150
# Epoch 112/150
# 1/1 - 0s - 103ms/step - loss: 0.0631 - root_mean_squared_error: 0.2512 - val_loss: 0.0816 - val_root_mean_squared_error: 0.2857
# Epoch 113/150
# 1/1 - 0s - 96ms/step - loss: 0.0630 - root_mean_squared_error: 0.2509 - val_loss: 0.0813 - val_root_mean_squared_error: 0.2851
# Epoch 114/150
# 1/1 - 0s - 108ms/step - loss: 0.0628 - root_mean_squared_error: 0.2506 - val_loss: 0.0811 - val_root_mean_squared_error: 0.2848
# Epoch 115/150
# 1/1 - 0s - 99ms/step - loss: 0.0626 - root_mean_squared_error: 0.2503 - val_loss: 0.0811 - val_root_mean_squared_error: 0.2847
# Epoch 116/150
# 1/1 - 0s - 110ms/step - loss: 0.0625 - root_mean_squared_error: 0.2499 - val_loss: 0.0811 - val_root_mean_squared_error: 0.2848
# Epoch 117/150
# 1/1 - 0s - 98ms/step - loss: 0.0623 - root_mean_squared_error: 0.2496 - val_loss: 0.0813 - val_root_mean_squared_error: 0.2851
# Epoch 118/150
# 1/1 - 0s - 101ms/step - loss: 0.0621 - root_mean_squared_error: 0.2492 - val_loss: 0.0815 - val_root_mean_squared_error: 0.2855
# Epoch 119/150
# 1/1 - 0s - 108ms/step - loss: 0.0619 - root_mean_squared_error: 0.2489 - val_loss: 0.0818 - val_root_mean_squared_error: 0.2860
# Epoch 120/150
# 1/1 - 0s - 98ms/step - loss: 0.0618 - root_mean_squared_error: 0.2485 - val_loss: 0.0822 - val_root_mean_squared_error: 0.2866
# Epoch 121/150
# 1/1 - 0s - 103ms/step - loss: 0.0616 - root_mean_squared_error: 0.2481 - val_loss: 0.0825 - val_root_mean_squared_error: 0.2873
# Epoch 122/150
# 1/1 - 0s - 93ms/step - loss: 0.0614 - root_mean_squared_error: 0.2478 - val_loss: 0.0829 - val_root_mean_squared_error: 0.2880
# Epoch 123/150
# 1/1 - 0s - 107ms/step - loss: 0.0612 - root_mean_squared_error: 0.2475 - val_loss: 0.0833 - val_root_mean_squared_error: 0.2887
# Epoch 124/150
# 1/1 - 0s - 107ms/step - loss: 0.0611 - root_mean_squared_error: 0.2471 - val_loss: 0.0837 - val_root_mean_squared_error: 0.2893
# Epoch 125/150
# 1/1 - 0s - 99ms/step - loss: 0.0609 - root_mean_squared_error: 0.2468 - val_loss: 0.0840 - val_root_mean_squared_error: 0.2898
# Epoch 126/150
# 1/1 - 0s - 100ms/step - loss: 0.0608 - root_mean_squared_error: 0.2465 - val_loss: 0.0842 - val_root_mean_squared_error: 0.2902
# Epoch 127/150
# 1/1 - 0s - 110ms/step - loss: 0.0606 - root_mean_squared_error: 0.2462 - val_loss: 0.0844 - val_root_mean_squared_error: 0.2906
# Epoch 128/150
# 1/1 - 0s - 95ms/step - loss: 0.0605 - root_mean_squared_error: 0.2459 - val_loss: 0.0846 - val_root_mean_squared_error: 0.2908
# Epoch 129/150
# 1/1 - 0s - 99ms/step - loss: 0.0603 - root_mean_squared_error: 0.2456 - val_loss: 0.0846 - val_root_mean_squared_error: 0.2909
# Epoch 130/150
# 1/1 - 0s - 86ms/step - loss: 0.0602 - root_mean_squared_error: 0.2453 - val_loss: 0.0846 - val_root_mean_squared_error: 0.2909
# Epoch 131/150
# 1/1 - 0s - 91ms/step - loss: 0.0600 - root_mean_squared_error: 0.2450 - val_loss: 0.0846 - val_root_mean_squared_error: 0.2908
# Epoch 132/150
# 1/1 - 0s - 97ms/step - loss: 0.0599 - root_mean_squared_error: 0.2447 - val_loss: 0.0844 - val_root_mean_squared_error: 0.2906
# Epoch 133/150
# 1/1 - 0s - 91ms/step - loss: 0.0597 - root_mean_squared_error: 0.2444 - val_loss: 0.0842 - val_root_mean_squared_error: 0.2902
# Epoch 134/150
# 1/1 - 0s - 99ms/step - loss: 0.0596 - root_mean_squared_error: 0.2441 - val_loss: 0.0840 - val_root_mean_squared_error: 0.2898
# Epoch 135/150
# 1/1 - 0s - 102ms/step - loss: 0.0595 - root_mean_squared_error: 0.2438 - val_loss: 0.0837 - val_root_mean_squared_error: 0.2894
# Epoch 136/150
# 1/1 - 0s - 112ms/step - loss: 0.0593 - root_mean_squared_error: 0.2436 - val_loss: 0.0834 - val_root_mean_squared_error: 0.2889
# Epoch 137/150
# 1/1 - 0s - 108ms/step - loss: 0.0592 - root_mean_squared_error: 0.2433 - val_loss: 0.0831 - val_root_mean_squared_error: 0.2883
# Epoch 138/150
# 1/1 - 0s - 95ms/step - loss: 0.0590 - root_mean_squared_error: 0.2430 - val_loss: 0.0828 - val_root_mean_squared_error: 0.2877
# Epoch 139/150
# 1/1 - 0s - 100ms/step - loss: 0.0589 - root_mean_squared_error: 0.2427 - val_loss: 0.0824 - val_root_mean_squared_error: 0.2871
# Epoch 140/150
# 1/1 - 0s - 103ms/step - loss: 0.0588 - root_mean_squared_error: 0.2424 - val_loss: 0.0821 - val_root_mean_squared_error: 0.2865
# Epoch 141/150
# 1/1 - 0s - 104ms/step - loss: 0.0586 - root_mean_squared_error: 0.2421 - val_loss: 0.0818 - val_root_mean_squared_error: 0.2860
# Epoch 142/150
# 1/1 - 0s - 100ms/step - loss: 0.0585 - root_mean_squared_error: 0.2419 - val_loss: 0.0815 - val_root_mean_squared_error: 0.2855
# Epoch 143/150
# 1/1 - 0s - 96ms/step - loss: 0.0584 - root_mean_squared_error: 0.2417 - val_loss: 0.0812 - val_root_mean_squared_error: 0.2850
# Epoch 144/150
# 1/1 - 0s - 100ms/step - loss: 0.0583 - root_mean_squared_error: 0.2414 - val_loss: 0.0810 - val_root_mean_squared_error: 0.2846
# Epoch 145/150
# 1/1 - 0s - 104ms/step - loss: 0.0582 - root_mean_squared_error: 0.2412 - val_loss: 0.0808 - val_root_mean_squared_error: 0.2843
# Epoch 146/150
# 1/1 - 0s - 112ms/step - loss: 0.0581 - root_mean_squared_error: 0.2410 - val_loss: 0.0807 - val_root_mean_squared_error: 0.2840
# Epoch 147/150
# 1/1 - 0s - 98ms/step - loss: 0.0580 - root_mean_squared_error: 0.2408 - val_loss: 0.0806 - val_root_mean_squared_error: 0.2838
# Epoch 148/150
# 1/1 - 0s - 99ms/step - loss: 0.0579 - root_mean_squared_error: 0.2406 - val_loss: 0.0805 - val_root_mean_squared_error: 0.2837
# Epoch 149/150
# 1/1 - 0s - 90ms/step - loss: 0.0578 - root_mean_squared_error: 0.2404 - val_loss: 0.0804 - val_root_mean_squared_error: 0.2836
# Epoch 150/150
# 1/1 - 0s - 104ms/step - loss: 0.0577 - root_mean_squared_error: 0.2402 - val_loss: 0.0804 - val_root_mean_squared_error: 0.2835

# %%
# Plot RMSE over epochs
plt.plot(history.history['root_mean_squared_error'])
plt.title('Root Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %%
# Evaluate the model
train_rmse = tlnn.evaluate(X_train, y_train, verbose=0)
test_rmse = tlnn.evaluate(X_test, y_test, verbose=0)
print("Train NRMSE:", train_rmse[1])
print("Test NRMSE:", test_rmse[1])
# Out:
# Train NRMSE: 0.23998799920082092
# Test NRMSE: 0.2834995687007904

# %%
# Predictions and inverse transformation
y_pred = tlnn.predict(X_test)
y_pred_orig = sc_y.inverse_transform(y_pred)
y_test_orig = sc_y.inverse_transform(y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step

# %%
# Visualization: Predictions vs Real Values
plt.figure(figsize=(10, 5))
plt.plot(range(len(y_test_orig)), y_test_orig, label='True Values', marker='o')
plt.plot(range(len(y_pred_orig)), y_pred_orig, label='Predictions', marker='x')
plt.xlabel('Index')
plt.ylabel('Solar Power Generation')
plt.title('True Values vs Predictions (TLNN)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Observations and Discussion
# The results from the preliminary testing seem very promising, so further testing will continue on the dataset

# %%
# Scale the data
sc_X = StandardScaler()
sc_y = StandardScaler()

X_lagged = sc_X.fit_transform(X_lagged)
y_lagged = sc_y.fit_transform(y_lagged.reshape(-1, 1))

# %%
# Train the model on the entire dataset
history = tlnn.fit(X_lagged, y_lagged, batch_size=32, epochs=150, verbose=2)
# Out:
# Epoch 1/150
# 1/1 - 0s - 31ms/step - loss: 0.0579 - root_mean_squared_error: 0.2407
# Epoch 2/150
# 1/1 - 0s - 55ms/step - loss: 0.0578 - root_mean_squared_error: 0.2404
# Epoch 3/150
# 1/1 - 0s - 31ms/step - loss: 0.0576 - root_mean_squared_error: 0.2400
# Epoch 4/150
# 1/1 - 0s - 28ms/step - loss: 0.0573 - root_mean_squared_error: 0.2394
# Epoch 5/150
# 1/1 - 0s - 38ms/step - loss: 0.0570 - root_mean_squared_error: 0.2387
# Epoch 6/150
# 1/1 - 0s - 32ms/step - loss: 0.0567 - root_mean_squared_error: 0.2381
# Epoch 7/150
# 1/1 - 0s - 29ms/step - loss: 0.0564 - root_mean_squared_error: 0.2376
# Epoch 8/150
# 1/1 - 0s - 37ms/step - loss: 0.0562 - root_mean_squared_error: 0.2372
# Epoch 9/150
# 1/1 - 0s - 36ms/step - loss: 0.0561 - root_mean_squared_error: 0.2368
# Epoch 66/150
# 1/1 - 0s - 38ms/step - loss: 0.0534 - root_mean_squared_error: 0.2311
# Epoch 67/150
# 1/1 - 0s - 30ms/step - loss: 0.0534 - root_mean_squared_error: 0.2311
# Epoch 68/150
# 1/1 - 0s - 26ms/step - loss: 0.0534 - root_mean_squared_error: 0.2310
# Epoch 69/150
# 1/1 - 0s - 44ms/step - loss: 0.0534 - root_mean_squared_error: 0.2310
# Epoch 70/150
# 1/1 - 0s - 57ms/step - loss: 0.0533 - root_mean_squared_error: 0.2309
# Epoch 71/150
# 1/1 - 0s - 43ms/step - loss: 0.0533 - root_mean_squared_error: 0.2309
# Epoch 72/150
# 1/1 - 0s - 26ms/step - loss: 0.0533 - root_mean_squared_error: 0.2309
# Epoch 73/150
# 1/1 - 0s - 29ms/step - loss: 0.0533 - root_mean_squared_error: 0.2309
# Epoch 74/150
# 1/1 - 0s - 64ms/step - loss: 0.0533 - root_mean_squared_error: 0.2308
# Epoch 75/150
# 1/1 - 0s - 42ms/step - loss: 0.0533 - root_mean_squared_error: 0.2308
# Epoch 76/150
# 1/1 - 0s - 48ms/step - loss: 0.0532 - root_mean_squared_error: 0.2307
# Epoch 77/150
# 1/1 - 0s - 32ms/step - loss: 0.0532 - root_mean_squared_error: 0.2307
# Epoch 78/150
# 1/1 - 0s - 57ms/step - loss: 0.0532 - root_mean_squared_error: 0.2307
# Epoch 79/150
# 1/1 - 0s - 38ms/step - loss: 0.0532 - root_mean_squared_error: 0.2306
# Epoch 80/150
# 1/1 - 0s - 37ms/step - loss: 0.0532 - root_mean_squared_error: 0.2306
# Epoch 81/150
# 1/1 - 0s - 34ms/step - loss: 0.0532 - root_mean_squared_error: 0.2306
# Epoch 82/150
# 1/1 - 0s - 30ms/step - loss: 0.0532 - root_mean_squared_error: 0.2306
# Epoch 83/150
# 1/1 - 0s - 57ms/step - loss: 0.0532 - root_mean_squared_error: 0.2305
# Epoch 84/150
# 1/1 - 0s - 30ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305
# Epoch 85/150
# 1/1 - 0s - 26ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305
# Epoch 86/150
# 1/1 - 0s - 28ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305
# Epoch 87/150
# 1/1 - 0s - 28ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305
# Epoch 88/150
# 1/1 - 0s - 29ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305
# Epoch 89/150
# 1/1 - 0s - 30ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305
# Epoch 90/150
# 1/1 - 0s - 34ms/step - loss: 0.0531 - root_mean_squared_error: 0.2304
# Epoch 91/150
# 1/1 - 0s - 33ms/step - loss: 0.0531 - root_mean_squared_error: 0.2304
# Epoch 92/150
# 1/1 - 0s - 33ms/step - loss: 0.0531 - root_mean_squared_error: 0.2304
# Epoch 93/150
# 1/1 - 0s - 50ms/step - loss: 0.0531 - root_mean_squared_error: 0.2304
# Epoch 94/150
# 1/1 - 0s - 36ms/step - loss: 0.0531 - root_mean_squared_error: 0.2304
# Epoch 95/150
# 1/1 - 0s - 33ms/step - loss: 0.0531 - root_mean_squared_error: 0.2303
# Epoch 96/150
# 1/1 - 0s - 34ms/step - loss: 0.0530 - root_mean_squared_error: 0.2303
# Epoch 97/150
# 1/1 - 0s - 37ms/step - loss: 0.0530 - root_mean_squared_error: 0.2303
# Epoch 98/150
# 1/1 - 0s - 32ms/step - loss: 0.0530 - root_mean_squared_error: 0.2303
# Epoch 99/150
# 1/1 - 0s - 30ms/step - loss: 0.0530 - root_mean_squared_error: 0.2303
# Epoch 100/150
# 1/1 - 0s - 29ms/step - loss: 0.0530 - root_mean_squared_error: 0.2302
# Epoch 101/150
# 1/1 - 0s - 38ms/step - loss: 0.0530 - root_mean_squared_error: 0.2302
# Epoch 102/150
# 1/1 - 0s - 43ms/step - loss: 0.0530 - root_mean_squared_error: 0.2302
# Epoch 103/150
# 1/1 - 0s - 31ms/step - loss: 0.0530 - root_mean_squared_error: 0.2302
# Epoch 104/150
# 1/1 - 0s - 47ms/step - loss: 0.0530 - root_mean_squared_error: 0.2302
# Epoch 105/150
# 1/1 - 0s - 34ms/step - loss: 0.0530 - root_mean_squared_error: 0.2302
# Epoch 106/150
# 1/1 - 0s - 33ms/step - loss: 0.0530 - root_mean_squared_error: 0.2302
# Epoch 107/150
# 1/1 - 0s - 54ms/step - loss: 0.0530 - root_mean_squared_error: 0.2301
# Epoch 108/150
# 1/1 - 0s - 31ms/step - loss: 0.0530 - root_mean_squared_error: 0.2301
# Epoch 109/150
# 1/1 - 0s - 31ms/step - loss: 0.0530 - root_mean_squared_error: 0.2301
# Epoch 110/150
# 1/1 - 0s - 54ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 111/150
# 1/1 - 0s - 51ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 112/150
# 1/1 - 0s - 40ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 113/150
# 1/1 - 0s - 36ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 114/150
# 1/1 - 0s - 31ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 115/150
# 1/1 - 0s - 28ms/step - loss: 0.0529 - root_mean_squared_error: 0.2301
# Epoch 116/150
# 1/1 - 0s - 34ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 117/150
# 1/1 - 0s - 39ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 118/150
# 1/1 - 0s - 36ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 119/150
# 1/1 - 0s - 34ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 120/150
# 1/1 - 0s - 54ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 121/150
# 1/1 - 0s - 35ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 122/150
# 1/1 - 0s - 29ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 123/150
# 1/1 - 0s - 29ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 124/150
# 1/1 - 0s - 33ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 125/150
# 1/1 - 0s - 30ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 126/150
# 1/1 - 0s - 29ms/step - loss: 0.0529 - root_mean_squared_error: 0.2300
# Epoch 127/150
# 1/1 - 0s - 35ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 128/150
# 1/1 - 0s - 28ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 129/150
# 1/1 - 0s - 30ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 130/150
# 1/1 - 0s - 27ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 131/150
# 1/1 - 0s - 27ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 132/150
# 1/1 - 0s - 28ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 133/150
# 1/1 - 0s - 33ms/step - loss: 0.0529 - root_mean_squared_error: 0.2299
# Epoch 134/150
# 1/1 - 0s - 28ms/step - loss: 0.0528 - root_mean_squared_error: 0.2299
# Epoch 135/150
# 1/1 - 0s - 26ms/step - loss: 0.0528 - root_mean_squared_error: 0.2299
# Epoch 136/150
# 1/1 - 0s - 32ms/step - loss: 0.0528 - root_mean_squared_error: 0.2299
# Epoch 137/150
# 1/1 - 0s - 32ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 138/150
# 1/1 - 0s - 28ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 139/150
# 1/1 - 0s - 26ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 140/150
# 1/1 - 0s - 33ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 141/150
# 1/1 - 0s - 28ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 142/150
# 1/1 - 0s - 28ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 143/150
# 1/1 - 0s - 27ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 144/150
# 1/1 - 0s - 29ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 145/150
# 1/1 - 0s - 28ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 146/150
# 1/1 - 0s - 27ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 147/150
# 1/1 - 0s - 30ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 148/150
# 1/1 - 0s - 27ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 149/150
# 1/1 - 0s - 28ms/step - loss: 0.0528 - root_mean_squared_error: 0.2298
# Epoch 150/150
# 1/1 - 0s - 35ms/step - loss: 0.0528 - root_mean_squared_error: 0.2297

# %%
# Plot RMSE over epochs
plt.plot(history.history['root_mean_squared_error'])
plt.title('Root Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %%
# Generate 12-month forecast
forecast_steps = 12
last_input = X_lagged[-1].reshape(1, -1)  # Start with the last input
predictions = []

for _ in range(forecast_steps):
    pred_scaled = tlnn.predict(last_input)  # Predict the next step
    pred = sc_y.inverse_transform(pred_scaled)[0, 0]  # Inverse transform the prediction
    predictions.append(pred)
    
    # Update input for the next prediction
    last_input = np.roll(last_input, -1)
    last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# C:\Users\brayk\AppData\Local\Temp\ipykernel_32836\2945854402.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   last_input[0, -1] = pred_scaled  # Add the new prediction to the input

# %%
# Plot the original data and forecast
plt.figure(figsize=(12, 6))

# Plot original data
plt.plot(range(len(utility_gen_values)), utility_gen_values, label='Original Data', linestyle='--', marker='o')

# Plot predictions
forecast_range = range(len(utility_gen_values), len(utility_gen_values) + forecast_steps)
plt.plot(forecast_range, predictions, label='12-Month Forecast', linestyle='-', marker='x')

# Adding labels, legend, and title
plt.xlabel('Time (Index)')
plt.ylabel('Solar Power Generation')
plt.title('12-Month Forecast vs Original Data')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Discussion
# Unfortunately, the TLNN was unable to forecast the seasonality of solar data, leading to a general downwards trend, which we can deem will be inaccurate. Thus, the TLNN will be dropped from further testing
